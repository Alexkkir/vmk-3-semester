# %%
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import matplotlib.animation as animation

plt.rcParams['animation.ffmpeg_path'] ='C:\\ffmpeg\\bin\\ffmpeg.exe'
fig=plt.figure()
ax=fig.add_subplot(111,projection="3d")

x=np.linspace(100,150,100)
t=(x-100)/0.5
y=-.01*np.cos(t)+.5*np.sin(t)+100.01
z=.01*np.sin(t)+.5*np.cos(t)+99.5

def animate(i):
    line.set_data(x[:i],y[:i])
    line.set_3d_properties(z[:i])
    return line,

ax.set_xlim3d([min(x),max(x)])
ax.set_ylim3d([min(y),max(y)])
ax.set_zlim3d([min(z),max(z)])
ax.set_title("Particle in magnetic field") 
ax.set_xlabel("X")
ax.set_xlabel("Y")
ax.set_xlabel("Z")
line,=ax.plot([],[],[])
lin_ani=animation.FuncAnimation(fig,animate)
plt.legend()

f = r"c://Users/1/Desktop/animation4.mp4" 
FFwriter = animation.FFMpegWriter()
lin_ani.save(f, writer = FFwriter, fps=10)
# Out:
# <img src="data:image/png;base64,..." width="640">
# No handles with labels found to put in legend.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-12-4a69a195c2ca> in <module>
#      31 f = r"c://Users/1/Desktop/animation4.mp4"
#      32 FFwriter = animation.FFMpegWriter()
# ---> 33 lin_ani.save(f, writer = FFwriter, fps=10)
#
# c:\users\1\appdata\local\programs\python\python39\lib\site-packages\matplotlib\animation.py in save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1086               any(arg is not None
#    1087                   for arg in (fps, codec, bitrate, extra_args, metadata))):
# -> 1088             raise RuntimeError('Passing in values for arguments '
#    1089                                'fps, codec, bitrate, extra_args, or metadata '
#    1090                                'is not supported when writer is an existing '
#
# RuntimeError: Passing in values for arguments fps, codec, bitrate, extra_args, or metadata is not supported when writer is an existing MovieWriter instance. These should instead be passed as arguments when creating the MovieWriter instance.

# %%
# %matplotlib notebook

import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation

fig = plt.figure()


# def f(x, y):
#     return np.sin(x) + np.cos(y)

# x = np.linspace(0, 2 * np.pi, 120)
# y = np.linspace(0, 2 * np.pi, 100).reshape(-1, 1)

# ims = []
# for i in range(60):
#     x += np.pi / 15.
#     y += np.pi / 20.
#     if i == 0:
#         print(f(x, y))
#     im = plt.imshow(f(x, y), animated=True)
    
#     ims.append([im])

x,y = [], []
def animate(i):
    x.append(i)
    y.append(random.randint(2,20))
    plt.style.use("ggplot")    
    plt.plot(x,y)

ani = animation.ArtistAnimation(fig, animate, interval=50, blit=True,
                                repeat_delay=1000)

# ani.save('dynamic_images.mp4')
writergif = animation.PillowWriter(fps=30) 
anim.save(f, writer=writergif)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-1c190dfebc6f> in <module>
#      31     plt.plot(x,y)
#      32
# ---> 33 ani = animation.ArtistAnimation(fig, animate, interval=50, blit=True,
#      34                                 repeat_delay=1000)
#      35
#
# c:\users\1\appdata\local\programs\python\python39\lib\site-packages\matplotlib\animation.py in __init__(self, fig, artists, *args, **kwargs)
#    1524         # over by the machinery.
#    1525         self._framedata = artists
# -> 1526         super().__init__(fig, *args, **kwargs)
#    1527
#    1528     def _init_draw(self):
#
# c:\users\1\appdata\local\programs\python\python39\lib\site-packages\matplotlib\animation.py in __init__(self, fig, interval, repeat_delay, repeat, event_source, *args, **kwargs)
#    1465         if event_source is None:
#    1466             event_source = fig.canvas.new_timer(interval=self._interval)
# -> 1467         super().__init__(fig, event_source=event_source, *args, **kwargs)
#    1468
#    1469     def _step(self, *args):
#
# c:\users\1\appdata\local\programs\python\python39\lib\site-packages\matplotlib\animation.py in __init__(self, fig, event_source, blit)
#     955         # drawing is handled by the subclasses. The event source fires events
#     956         # that cause the frame sequence to be iterated.
# --> 957         self.frame_seq = self.new_frame_seq()
#     958         self.event_source = event_source
#     959
#
# c:\users\1\appdata\local\programs\python\python39\lib\site-packages\matplotlib\animation.py in new_frame_seq(self)
#    1195         """Return a new sequence of frame information."""
#    1196         # Default implementation is just an iterator over self._framedata
# -> 1197         return iter(self._framedata)
#    1198
#    1199     def new_saved_frame_seq(self):
#
# TypeError: 'function' object is not iterable

# %%
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
import random
# %matplotlib qt

fig = plt.figure(figsize=(6,4))
axes = fig.add_subplot(1,1,1)
plt.title("Dynamic Axes")

y1 = [random.randint(-10,10)+(i**1.6)/(random.randint(9,12)) for i in range(0,280,2)]
t = range(len(y1))
x,y=[], []

def animate(i):
    x.append(t[i])
    y.append((y1[i]))
    plt.xlim(i-30,i+3)
    axes.set_ylim(y1[i]-100, y1[i]+100)
    plt.plot(x,y, scaley=True, scalex=True, color="red")

anim = FuncAnimation(fig, animate, interval=100)
# Out:
# Warning: Cannot change to a different GUI toolkit: qt. Using notebook instead.
# <img src="data:image/png;base64,..." width="600">
# c:\users\1\appdata\local\programs\python\python39\lib\site-packages\matplotlib\animation.py:973: UserWarning: Animation was deleted without rendering anything. This is most likely unintended. To prevent deletion, assign the Animation to a variable that exists for as long as you need the Animation.
#   warnings.warn(

# %%
# %matplotlib notebook

import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation

def fun(i, block_size=16):
    fig = plt.figure()
    def f(x, y):
        return np.sin(x) + np.cos(y)

    x = np.linspace(0, 2 * np.pi, 120)
    y = np.linspace(0, 2 * np.pi, 100).reshape(-1, 1)
    x += np.pi / 15 * i
    y += np.pi / 20 * i
    plt.imshow(f(x, y), animated=True)
    
    return fig
    
ims = []
for i in range(60):

    im = plt.imshow(fun(i), animated=True)
    ims.append([im])

ani = animation.ArtistAnimation(, ims, interval=30, blit=True,
                                repeat_delay=1000)

a = fun(
            result['source_frames'][25],
            result['ofs'][25]
        )
# Out:
# <img src="data:image/png;base64,..." width="640">
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-5d25d4850244> in <module>
#      21 for i in range(60):
#      22
# ---> 23     im = plt.imshow(fun(i), animated=True)
#      24     ims.append([im])
#      25
#
# c:\users\1\appdata\local\programs\python\python39\lib\site-packages\matplotlib\pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, filternorm, filterrad, resample, url, data, **kwargs)
#    2901         filternorm=True, filterrad=4.0, resample=None, url=None,
#    2902         data=None, **kwargs):
# -> 2903     __ret = gca().imshow(
#    2904         X, cmap=cmap, norm=norm, aspect=aspect,
#    2905         interpolation=interpolation, alpha=alpha, vmin=vmin,
#
# c:\users\1\appdata\local\programs\python\python39\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1359     def inner(ax, *args, data=None, **kwargs):
#    1360         if data is None:
# -> 1361             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1362
#    1363         bound = new_sig.bind(ax, *args, **kwargs)
#
# c:\users\1\appdata\local\programs\python\python39\lib\site-packages\matplotlib\axes\_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, filternorm, filterrad, resample, url, **kwargs)
#    5607                               resample=resample, **kwargs)
#    5608
# -> 5609         im.set_data(X)
#    5610         im.set_alpha(alpha)
#    5611         if im.get_clip_path() is None:
#
# c:\users\1\appdata\local\programs\python\python39\lib\site-packages\matplotlib\image.py in set_data(self, A)
#     698         if (self._A.dtype != np.uint8 and
#     699                 not np.can_cast(self._A.dtype, float, "same_kind")):
# --> 700             raise TypeError("Image data of dtype {} cannot be converted to "
#     701                             "float".format(self._A.dtype))
#     702
#
# TypeError: Image data of dtype object cannot be converted to float

# %%
import random
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation

fig = plt.figure(figsize=(5, 5))


x,y = [], []
def animate(i):
    x.append(i)
    y.append(random.randint(2,20))
    plt.style.use("ggplot")    
    plt.plot(x,y)

ani = FuncAnimation(fig, animate, interval=300)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="499.55555555555554">
